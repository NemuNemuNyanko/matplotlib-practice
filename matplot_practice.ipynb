# %%
import matplotlib as mlp
import matplotlib.pyplot as plt

import numpy as np

# %%
x = np.linspace(0,10,100)

fig = plt.figure()
plt.plot(x,np.sin(x),linestyle=  ":")
plt.plot(x,np.cos(x))
plt.show()

# %%
fig.savefig("graph.png")

# %%
plt.figure()

plt.subplot(2,2,1)
plt.plot(x,np.sin(x),color = "red")

plt.subplot(2,2,2)
plt.plot(x,np.cos(x),color = "blue")

plt.subplot(2,2,3)
plt.plot(x,np.sin(x),color = "green")

plt.subplot(2,2,4)
plt.plot(x,np.sin(x),color = "black")

plt.show()

# %%
plt.figure()

plt.plot(x,np.sin(x),color = "red",label = "sin(x)")
plt.plot(x,np.cos(x),color = "blue",label = "cos(x)")

plt.title("graph")
plt.xlabel("x")
plt.ylabel("y")

plt.grid() # 格子線
plt.legend() # 凡例の表示

plt.show()

# %% [markdown]
# # 散布図

# %%
x = np.linspace(-5,5,30) 
y = x + np.random.randn(30) * 0.5

x2 = np.linspace(-5,5,30) 
y2 = -x2 + np.random.randn(30) * 0.5

plt.figure()

plt.scatter(x,y,color = "red", label = "unk")
plt.scatter(x2,y2,color = "blue", label = "mnk")

plt.legend()
plt.show()

# %% [markdown]
# # 縦棒

# %%
plt.figure()

fig, ax = plt.subplots()

X = ["unk","mnk","sex","has"]
Y = np.array([100,99,50,150])

bar_labels = ['red', 'red', 'mnk', 'unf']
bar_colors = ['tab:red', 'tab:red', 'tab:blue', 'tab:orange']

ax.bar(X,Y,label = bar_labels ,color = bar_colors )
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np

species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(species,x + width)

ax.legend(loc='upper left', ncol=3)
ax.set_ylim(0, 250)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3780/3420071093.py in <module>
#      26 ax.set_ylabel('Length (mm)')
#      27 ax.set_title('Penguin attributes by species')
# ---> 28 ax.set_xticks(species,x + width)
#      29
#      30 ax.legend(loc='upper left', ncol=3)
#
# d:\Users\4regi\anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# TypeError: set_ticks() takes 2 positional arguments but 3 were given

# %%
x + width
# Out:
# array([0.25, 1.25, 2.25])

# %%
species
# Out:
# ('Adelie', 'Chinstrap', 'Gentoo')

# %% [markdown]
# # chatGPT 複数グループの棒グラフ

# %%
groups = ['point', 'saishyu', 'CB']
categories = ['parameter1', 'parameter2', 'parameter3']

data = np.array([
    [10, 15, 20],
    [25, 30, 35],
    [5, 12, 18]
])

# %%
bar_width = 0.2  # 各カテゴリの棒の幅
x_positions = np.arange(len(categories))  # カテゴリの数だけX軸の位置を生成

# 各グループごとに棒グラフを描画
for i, group_data in enumerate(data):
    plt.bar(x_positions + i * bar_width, group_data, width=bar_width, label=groups[i])

plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Grouped Bar Chart')
plt.xticks(x_positions + bar_width * (len(groups) - 1) / 2, categories)  # カテゴリ名を設定
plt.legend()

plt.tight_layout()
plt.show()
